# %% [markdown]
# <a href="https://colab.research.google.com/github/geethatathireddy/play-store-project/blob/main/Google_playstore_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %% [markdown]
# ![Jeff-Bezos-Quotes-Images1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Since the reign of digital revolution, we are more connected to internet. In the fast changing economy, business, organisations, jobs, and most of the work is transformed online. we can demand almost anything with single click.
#
#
# ## *   Hungry? Grab a pizza from Zomato, Swiggy, Foodpanda etc. Provides fast delivery, safe and hygenic with maintaining qaulity standards.
#
# ## *   want lifestyle wears, Groceries, Electronics, almost anything you wish ? Amazon is there..
#
# ## *   Trip to Goa with 3 idiots or 3 musketiers ? MakemyTrip is there.

# %% [markdown]
# # The above Quote perfectly hints that for a successful company, customer experience is important.
#
# # Below are key questions are important for every company to make successfull business.
#
# 1.   who is the target customer and What are the needs of customer ?
# 2.   what are the likes and dislikes ?
# 3.   what are the reviews and feedbacks ?
# 4.   is the customer retained ?
# 5.   how much customer is satisfied the service / product ?

# %% [markdown]
# # Step : 1  INTRODUCTION TO DATA
#
# Firstly let's get to know data. While I was analyzing the data, I used Pandas library.
#
# *   info(): It informs about data columns and data types.
# *   head(): It returns the first five data.
# *   tail(): It returns the last five data.
# *   columns : It returns data columns.
# *   shape : It gives number of rows and c
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# olumns in a tuble.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dir_path_playstore = '/content/drive/MyDrive/projects/Play Store Data.csv'

# %%
dir_path_reviews = '/content/drive/MyDrive/projects/User Reviews.csv'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %%
df_playstore = pd.read_csv(dir_path_playstore)
df_reviews = pd.read_csv(dir_path_reviews)

# %% [markdown]
# # Let's See the Meta data of both Play Store and User Reviews.

# %%
df_playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44260 entries, 0 to 44259
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     44260 non-null  object
#  1   Translated_Review       25609 non-null  object
#  2   Sentiment               25612 non-null  object
#  3   Sentiment_Polarity      25612 non-null  float64
#  4   Sentiment_Subjectivity  25612 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.7+ MB

# %% [markdown]
#  Now, we deep dive into data contents of both data frames.

# %%
df_playstore.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df_playstore.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
df_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
df_reviews.tail()
# Out:
#                                   App  \
# 44255  Fantasy Football Manager (FPL)
# 44256  Fantasy Football Manager (FPL)
# 44257  Fantasy Football Manager (FPL)
# 44258  Fantasy Football Manager (FPL)
# 44259  Fantasy Football Manager (FPL)
#
#                                        Translated_Review Sentiment  \
# 44255                                          Fantastic  Positive
# 44256  phone language arabic flopped , please pix it....  Positive
# 44257  I think system whereby defensive midfielders g...   Neutral
# 44258  Pretty simple fast, gets job done. No complain...  Positive
# 44259                     The attracting. But need send        NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 44255            0.400000                0.900000
# 44256            0.100000                0.200000
# 44257            0.000000                0.000000
# 44258            0.113889                0.670635
# 44259                 NaN                     NaN

# %%
df_playstore.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_playstore.shape
# Out:
# (10841, 13)

# %% [markdown]
# # 2. Cleaning Data - Dataset can contain missing data, numerical string value, various cues. If we can clean them, we can make easy our analysis.
#
# Content Rating

# %%
df_playstore['Content Rating'].value_counts()
# Out:
# Everyone           8714
# Teen               1208
# Mature 17+          499
# Everyone 10+        414
# Adults only 18+       3
# Unrated               2
# Name: Content Rating, dtype: int64

# %%
df_playstore.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df_playstore.columns=df_playstore.columns.str.replace(' ','')

# %%
df_playstore.ContentRating.fillna(value='Everyone',inplace=True)

# %%
df_playstore.Rating.fillna(value=4.1,inplace=True)
df_playstore.Type.fillna(value='Free',inplace=True)

# %% [markdown]
# Reviews

# %%
df_playstore['Reviews'] = df_playstore['Reviews'].str.replace('M', '', regex=True).astype(float)

# %%
df_playstore['Reviews']
# Out:
# 0           159.0
# 1           967.0
# 2         87510.0
# 3        215644.0
# 4           967.0
#            ...
# 10836        38.0
# 10837         4.0
# 10838         3.0
# 10839       114.0
# 10840    398307.0
# Name: Reviews, Length: 10841, dtype: float64

# %%
df_playstore = df_playstore.drop(10472)

# %% [markdown]
# Installs

# %%
df_playstore['Installs']
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10840, dtype: object

# %%
df_playstore['Installs'] = df_playstore['Installs'].str.replace("['+,']", '', regex=True).astype(float)

# %%
df_playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   App            10840 non-null  object
#  1   Category       10840 non-null  object
#  2   Rating         10840 non-null  float64
#  3   Reviews        10840 non-null  float64
#  4   Size           10840 non-null  object
#  5   Installs       10840 non-null  float64
#  6   Type           10840 non-null  object
#  7   Price          10840 non-null  object
#  8   ContentRating  10840 non-null  object
#  9   Genres         10840 non-null  object
#  10  LastUpdated    10840 non-null  object
#  11  CurrentVer     10832 non-null  object
#  12  AndroidVer     10838 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 1.2+ MB

# %%
df_playstore.drop(labels=['LastUpdated','CurrentVer','AndroidVer'], axis=1,inplace=True)

# %% [markdown]
# Size

# %%
df_playstore.drop(labels=['Size'], axis=1,inplace=True)

# %%
df_playstore.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews    Installs  Type Price ContentRating                     Genres
# 0     159.0     10000.0  Free     0      Everyone               Art & Design
# 1     967.0    500000.0  Free     0      Everyone  Art & Design;Pretend Play
# 2   87510.0   5000000.0  Free     0      Everyone               Art & Design
# 3  215644.0  50000000.0  Free     0          Teen               Art & Design
# 4     967.0    100000.0  Free     0      Everyone    Art & Design;Creativity

# %%
df_playstore.columns=df_playstore.columns.str.replace(' ','')

# %% [markdown]
# Price

# %%
df_playstore['Price']=df_playstore.Price.apply(lambda x:x.strip('$')).astype(float)

# %%
df_playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   App            10840 non-null  object
#  1   Category       10840 non-null  object
#  2   Rating         10840 non-null  float64
#  3   Reviews        10840 non-null  float64
#  4   Installs       10840 non-null  float64
#  5   Type           10840 non-null  object
#  6   Price          10840 non-null  float64
#  7   ContentRating  10840 non-null  object
#  8   Genres         10840 non-null  object
# dtypes: float64(4), object(5)
# memory usage: 846.9+ KB

# %%
df_reviews.isnull().sum()
# Out:
# App                           0
# Translated_Review         18651
# Sentiment                 18648
# Sentiment_Polarity        18648
# Sentiment_Subjectivity    18648
# dtype: int64

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# Rating
# *   Data type of Rating is object. If we convert from string to numeric, we can
#     make easy.

# %%
df_playstore['Rating'].fillna(df_playstore['Rating'].median(),inplace=True)

# %%
df_playstore.drop_duplicates()
# Out:
#                                                      App  ...                     Genres
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...               Art & Design
# 1                                    Coloring book moana  ...  Art & Design;Pretend Play
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...               Art & Design
# 3                                  Sketch - Draw & Paint  ...               Art & Design
# 4                  Pixel Draw - Number Art Coloring Book  ...    Art & Design;Creativity
# ...                                                  ...  ...                        ...
# 10836                                   Sya9a Maroc - FR  ...                  Education
# 10837                   Fr. Mike Schmitz Audio Teachings  ...                  Education
# 10838                             Parkinson Exercices FR  ...                    Medical
# 10839                      The SCP Foundation DB fr nn5n  ...          Books & Reference
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...                  Lifestyle
#
# [10355 rows x 9 columns]

# %% [markdown]
# Category

# %%
df_playstore[df_playstore['Category']=='ART_AND_DESIGN'].value_counts().reset_index()
# Out:
#                                                   App  ...  0
# 0                                           صور حرف H  ...  1
# 1                     Learn To Draw Kawaii Characters  ...  1
# 2   Install images with music to make video withou...  ...  1
# 3                                    Infinite Painter  ...  1
# 4                                     I Creative Idea  ...  1
# ..                                                ...  ... ..
# 60            Name Art Photo Editor - Focus n Filters  ...  1
# 61             Name Art DP - Focus n Filter Text 2018  ...  1
# 62                             Mcqueen Coloring pages  ...  1
# 63                              Mandala Coloring Book  ...  1
# 64                           350 Diy Room Decor Ideas  ...  1
#
# [65 rows x 10 columns]

# %%
df_art_and_design = df_playstore[df_playstore['Category']=='ART_AND_DESIGN'].value_counts().reset_index()

# %%
def review_percentage(data1,data2):
  return (data1/data2)*100

# %%
df_art_and_design['Review_percent'] = review_percentage(df_art_and_design['Reviews'],df_art_and_design['Installs'])

# %%
df_art_and_design.head()
# Out:
#                                        App        Category  Rating  Reviews  \
# 0                 350 Diy Room Decor Ideas  ART_AND_DESIGN     4.5     27.0
# 1              Logo Maker - Small Business  ART_AND_DESIGN     4.0    450.0
# 2                   Mcqueen Coloring pages  ART_AND_DESIGN     4.1     61.0
# 3   Name Art DP - Focus n Filter Text 2018  ART_AND_DESIGN     4.3    132.0
# 4  Name Art Photo Editor - Focus n Filters  ART_AND_DESIGN     4.4   8788.0
#
#     Installs  Type  Price ContentRating                           Genres  0  \
# 0    10000.0  Free    0.0      Everyone                     Art & Design  1
# 1   100000.0  Free    0.0      Everyone                     Art & Design  1
# 2   100000.0  Free    0.0      Everyone  Art & Design;Action & Adventure  1
# 3    10000.0  Free    0.0      Everyone                     Art & Design  1
# 4  1000000.0  Free    0.0      Everyone                     Art & Design  1
#
#    Review_percent
# 0          0.2700
# 1          0.4500
# 2          0.0610
# 3          1.3200
# 4          0.8788

# %%
df_art_and_design['Installs'].mean()
# Out:
# 1912893.8461538462

# %%
df_art_and_design['Reviews'].mean()
# Out:
# 26376.0

# %%
df_higher_mean_installs = df_art_and_design[df_art_and_design['Installs'] > df_art_and_design['Installs'].mean()]

# %%
df_higher_mean_installs.drop_duplicates('App')
# Out:
#                                                   App        Category  Rating  \
# 15                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 19                     Tattoo Name On My Photo Editor  ART_AND_DESIGN     4.2
# 22                         Textgram - write on photos  ART_AND_DESIGN     4.4
# 24  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 30                                       ibis Paint X  ART_AND_DESIGN     4.6
# 42  Canva: Poster, banner, card maker & graphic de...  ART_AND_DESIGN     4.7
# 52                      FlipaClip - Cartoon animation  ART_AND_DESIGN     4.3
# 53                                 Floor Plan Creator  ART_AND_DESIGN     4.1
#
#      Reviews    Installs  Type  Price ContentRating        Genres  0  \
# 15  215644.0  50000000.0  Free    0.0          Teen  Art & Design  1
# 19   44829.0  10000000.0  Free    0.0          Teen  Art & Design  1
# 22  295221.0  10000000.0  Free    0.0      Everyone  Art & Design  1
# 24   87510.0   5000000.0  Free    0.0      Everyone  Art & Design  1
# 30  224399.0  10000000.0  Free    0.0      Everyone  Art & Design  1
# 42  174531.0  10000000.0  Free    0.0      Everyone  Art & Design  1
# 52  194216.0   5000000.0  Free    0.0      Everyone  Art & Design  1
# 53   36639.0   5000000.0  Free    0.0      Everyone  Art & Design  1
#
#     Review_percent
# 15        0.431288
# 19        0.448290
# 22        2.952210
# 24        1.750200
# 30        2.243990
# 42        1.745310
# 52        3.884320
# 53        0.732780

# %%
df_higher_mean_review =  df_art_and_design[df_art_and_design['Reviews'] > df_art_and_design['Reviews'].mean()]

# %%
df_higher_mean_review.drop_duplicates('App')
# Out:
#                                                   App        Category  Rating  \
# 15                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 19                     Tattoo Name On My Photo Editor  ART_AND_DESIGN     4.2
# 22                         Textgram - write on photos  ART_AND_DESIGN     4.4
# 24  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 30                                       ibis Paint X  ART_AND_DESIGN     4.6
# 42  Canva: Poster, banner, card maker & graphic de...  ART_AND_DESIGN     4.7
# 52                      FlipaClip - Cartoon animation  ART_AND_DESIGN     4.3
# 53                                 Floor Plan Creator  ART_AND_DESIGN     4.1
# 61                                   Infinite Painter  ART_AND_DESIGN     4.1
#
#      Reviews    Installs  Type  Price ContentRating        Genres  0  \
# 15  215644.0  50000000.0  Free    0.0          Teen  Art & Design  1
# 19   44829.0  10000000.0  Free    0.0          Teen  Art & Design  1
# 22  295221.0  10000000.0  Free    0.0      Everyone  Art & Design  1
# 24   87510.0   5000000.0  Free    0.0      Everyone  Art & Design  1
# 30  224399.0  10000000.0  Free    0.0      Everyone  Art & Design  1
# 42  174531.0  10000000.0  Free    0.0      Everyone  Art & Design  1
# 52  194216.0   5000000.0  Free    0.0      Everyone  Art & Design  1
# 53   36639.0   5000000.0  Free    0.0      Everyone  Art & Design  1
# 61   36815.0   1000000.0  Free    0.0      Everyone  Art & Design  1
#
#     Review_percent
# 15        0.431288
# 19        0.448290
# 22        2.952210
# 24        1.750200
# 30        2.243990
# 42        1.745310
# 52        3.884320
# 53        0.732780
# 61        3.681500

# %%
df_higher_mean_review.shape
# Out:
# (10, 11)

# %%
df_engage_art_and_design = pd.merge(df_higher_mean_installs,df_higher_mean_review,on='App')

# %%
df_engage_art_and_design.drop_duplicates('App')
# Out:
#                                                   App      Category_x  \
# 0                               Sketch - Draw & Paint  ART_AND_DESIGN
# 1                      Tattoo Name On My Photo Editor  ART_AND_DESIGN
# 2                          Textgram - write on photos  ART_AND_DESIGN
# 6   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 7                                        ibis Paint X  ART_AND_DESIGN
# 8   Canva: Poster, banner, card maker & graphic de...  ART_AND_DESIGN
# 9                       FlipaClip - Cartoon animation  ART_AND_DESIGN
# 10                                 Floor Plan Creator  ART_AND_DESIGN
#
#     Rating_x  Reviews_x  Installs_x Type_x  Price_x ContentRating_x  \
# 0        4.5   215644.0  50000000.0   Free      0.0            Teen
# 1        4.2    44829.0  10000000.0   Free      0.0            Teen
# 2        4.4   295221.0  10000000.0   Free      0.0        Everyone
# 6        4.7    87510.0   5000000.0   Free      0.0        Everyone
# 7        4.6   224399.0  10000000.0   Free      0.0        Everyone
# 8        4.7   174531.0  10000000.0   Free      0.0        Everyone
# 9        4.3   194216.0   5000000.0   Free      0.0        Everyone
# 10       4.1    36639.0   5000000.0   Free      0.0        Everyone
#
#         Genres_x  0_x  ...      Category_y Rating_y  Reviews_y  Installs_y  \
# 0   Art & Design    1  ...  ART_AND_DESIGN      4.5   215644.0  50000000.0
# 1   Art & Design    1  ...  ART_AND_DESIGN      4.2    44829.0  10000000.0
# 2   Art & Design    1  ...  ART_AND_DESIGN      4.4   295221.0  10000000.0
# 6   Art & Design    1  ...  ART_AND_DESIGN      4.7    87510.0   5000000.0
# 7   Art & Design    1  ...  ART_AND_DESIGN      4.6   224399.0  10000000.0
# 8   Art & Design    1  ...  ART_AND_DESIGN      4.7   174531.0  10000000.0
# 9   Art & Design    1  ...  ART_AND_DESIGN      4.3   194216.0   5000000.0
# 10  Art & Design    1  ...  ART_AND_DESIGN      4.1    36639.0   5000000.0
#
#     Type_y Price_y  ContentRating_y      Genres_y 0_y  Review_percent_y
# 0     Free     0.0             Teen  Art & Design   1          0.431288
# 1     Free     0.0             Teen  Art & Design   1          0.448290
# 2     Free     0.0         Everyone  Art & Design   1          2.952210
# 6     Free     0.0         Everyone  Art & Design   1          1.750200
# 7     Free     0.0         Everyone  Art & Design   1          2.243990
# 8     Free     0.0         Everyone  Art & Design   1          1.745310
# 9     Free     0.0         Everyone  Art & Design   1          3.884320
# 10    Free     0.0         Everyone  Art & Design   1          0.732780
#
# [8 rows x 21 columns]

# %%
df_engage_art_and_design = df_engage_art_and_design.sort_values(by='Review_percent_x', ascending=False).drop_duplicates('App')

# %%
df_engage_art_and_design.head()
# Out:
#                                                  App      Category_x  \
# 9                      FlipaClip - Cartoon animation  ART_AND_DESIGN
# 4                         Textgram - write on photos  ART_AND_DESIGN
# 7                                       ibis Paint X  ART_AND_DESIGN
# 6  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 8  Canva: Poster, banner, card maker & graphic de...  ART_AND_DESIGN
#
#    Rating_x  Reviews_x  Installs_x Type_x  Price_x ContentRating_x  \
# 9       4.3   194216.0   5000000.0   Free      0.0        Everyone
# 4       4.4   295237.0  10000000.0   Free      0.0        Everyone
# 7       4.6   224399.0  10000000.0   Free      0.0        Everyone
# 6       4.7    87510.0   5000000.0   Free      0.0        Everyone
# 8       4.7   174531.0  10000000.0   Free      0.0        Everyone
#
#        Genres_x  0_x  ...      Category_y Rating_y  Reviews_y  Installs_y  \
# 9  Art & Design    1  ...  ART_AND_DESIGN      4.3   194216.0   5000000.0
# 4  Art & Design    1  ...  ART_AND_DESIGN      4.4   295221.0  10000000.0
# 7  Art & Design    1  ...  ART_AND_DESIGN      4.6   224399.0  10000000.0
# 6  Art & Design    1  ...  ART_AND_DESIGN      4.7    87510.0   5000000.0
# 8  Art & Design    1  ...  ART_AND_DESIGN      4.7   174531.0  10000000.0
#
#    Type_y Price_y  ContentRating_y      Genres_y 0_y  Review_percent_y
# 9    Free     0.0         Everyone  Art & Design   1           3.88432
# 4    Free     0.0         Everyone  Art & Design   1           2.95221
# 7    Free     0.0         Everyone  Art & Design   1           2.24399
# 6    Free     0.0         Everyone  Art & Design   1           1.75020
# 8    Free     0.0         Everyone  Art & Design   1           1.74531
#
# [5 rows x 21 columns]

# %%
df_playstore['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , 4.8, 4.9,
#        3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8, 2.7,
#        1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5, 1.2])

# %% [markdown]
# # Data Exploration and visualisation

# %% [markdown]
# # What are the top 10 apps highest installed in each category ?

# %%
#code here
def findtop10incategory(str):
    str = str.upper()
    top10 = df_playstore[df_playstore['Category'] == str]
    top10apps = top10.sort_values(by='Installs', ascending=False).head(10)
    # Top_Apps_in_art_and_design
    plt.figure(figsize=(6,6))
    plt.title('Top 10 Installed Apps',size = 20);    
    graph = sns.barplot(x = top10apps.App, y = top10apps.Installs)
    graph.set_xticklabels(graph.get_xticklabels(), rotation= 45, horizontalalignment='right');

# %%
findtop10incategory('Beauty')

# %% [markdown]
# The above bar chart represents Top 10 Highest Installed apps of particular category. In this way we can find and plot top 10 highest installed apps for any category by changing category name in the statement below:                  *findtop10incategory('Category_Name')*.

# %% [markdown]
# # How many are free app and paid app among all dataset ?

# %%
#code here
plt.figure(figsize=(10,5))
labels = df_playstore['Type'].value_counts(sort = True).index
sizes = df_playstore['Type'].value_counts(sort = True)
colors = ["cyan","yellow"]
plt.pie(sizes, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True, startangle=0,textprops={'fontsize': 15})

plt.title('Percent of Free Vs Paid Apps in store',size = 20)
plt.show()

# %% [markdown]
# The above Pie-Chart represents percentage of Free apps are 92.6% and paid apps are 7.4% in dataset.

# %% [markdown]
# # Distribution curve of ratings in each categories ?

# %%
#code here
plt.figure(figsize=(11,7))
plt.xlabel("Rating")
plt.ylabel("Frequency")
graph = sns.kdeplot(df_playstore.Rating, color="Blue", shade = True)
plt.title('Distribution of Rating',size = 20);

# %% [markdown]
# # Percentage User Review per app
# # hint : (review/installs)*100, review mean, installs mean

# %%
def review_percentage(data1,data2):
  return (data1/data2)*100

# %%
# code here
def user_review_percent(data1):
  data_string = data1.upper()
  df_user_review = df_playstore[df_playstore['Category']==data_string].value_counts().reset_index()
  df_user_review['Review_percent'] = review_percentage(df_user_review['Reviews'],df_user_review['Installs'])
  df_higher_mean_installs = df_user_review[df_user_review['Installs'] > df_user_review['Installs'].mean()]
  df_higher_mean_review =  df_user_review[df_user_review['Reviews'] > df_user_review['Reviews'].mean()]
  df_engagement = pd.merge(df_higher_mean_installs,df_higher_mean_review,on='App')
  df_engagement = df_engagement.sort_values(by='Review_percent_x', ascending=False).drop_duplicates('App')
  return df_engagement.shape[0]

# %%
user_review_percent('Beauty')
# Out:
# 9

# %%
category_list = list(df_playstore['Category'].unique())

# %%
category_list[0]
# Out:
# 'ART_AND_DESIGN'

# %%
df_playstore['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
def plot_user_engagement(list1):
  global list2 
  list2 = []
  for n in list1:
    list2.append(user_review_percent(n))

  plt.figure(figsize=(7,10))
  font1 = {'family':'serif','color':'blue','size':20}
  font2 = {'family':'serif','color':'darkred','size':15}
  plt.title("Most Engaging Category", fontdict = font1)
  plt.xlabel("Number of Apps", fontdict = font2)
  plt.ylabel("Category", fontdict = font2)
  x = np.array(list1)
  y = np.array(list2)
  plt.barh(x,y,height=0.5)
  plt.show()

# %%
plot_user_engagement(category_list)

# %% [markdown]
# Correlation

# %%
df_playstore.corr()
# Out:
#             Rating   Reviews  Installs     Price
# Rating    1.000000  0.071816  0.055838 -0.020834
# Reviews   0.071816  1.000000  0.643122 -0.009667
# Installs  0.055838  0.643122  1.000000 -0.011689
# Price    -0.020834 -0.009667 -0.011689  1.000000

# %%
##correlation map
f,ax = plt.subplots(figsize=(12, 12))
sns.heatmap(df_playstore.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %% [markdown]
# describe (): It returns number of entries, average of entries, outlier values, standart deviation, minimum and maximum entry.

# %%
df_playstore.describe()
# Out:
#              Rating       Reviews      Installs         Price
# count  10840.000000  1.084000e+04  1.084000e+04  10840.000000
# mean       4.179280  4.441529e+05  1.546434e+07      1.027368
# std        0.479939  2.927761e+06  8.502936e+07     15.949703
# min        1.000000  0.000000e+00  0.000000e+00      0.000000
# 25%        4.100000  3.800000e+01  1.000000e+03      0.000000
# 50%        4.200000  2.094000e+03  1.000000e+05      0.000000
# 75%        4.500000  5.477550e+04  5.000000e+06      0.000000
# max        5.000000  7.815831e+07  1.000000e+09    400.000000

# %% [markdown]
# Box plot

# %%
Category1 = df_playstore[df_playstore.Category=="GAME"].Rating
Category2 = df_playstore[df_playstore.Category=="FAMILY"].Rating
Category3 = df_playstore[df_playstore.Category=="MEDICAL"].Rating
Category4 = df_playstore[df_playstore.Category=="TOOLS"].Rating
Category5 = df_playstore[df_playstore.Category=="HEALTH_AND_FITNESS"].Rating
fig = go.Figure()
# Use x instead of y argument for horizontal plot
fig.add_trace(go.Box(x=Category1, name='GAME'))
fig.add_trace(go.Box(x=Category2, name='FAMILY'))
fig.add_trace(go.Box(x=Category3, name='MEDICAL'))
fig.add_trace(go.Box(x=Category3, name='TOOLS'))
fig.add_trace(go.Box(x=Category3, name='HEALTH_AND_FITNESS'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="292e993b-8d59-49f4-8c4a-753fe4dc3740" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("292e993b-8d59-49f4-8c4a-753fe4dc3740")) {                    Plotly.newPlot(                        "292e993b-8d59-49f4-8c4a-753fe4dc3740",                        [{"name":"GAME","x":[4.5,4.5,4.4,4.7,4.5,4.2,4.4,4.6,4.3,4.3,4.2,4.6,4.4,4.4,4.5,4.4,4.3,4.6,4.3,4.2,4.2,4.5,4.5,4.5,4.7,4.7,4.5,4.4,4.3,3.8,4.6,4.6,4.4,4.3,4.1,4.3,4.4,4.6,4.3,4.4,4.7,4.5,4.4,4.6,4.5,4.4,4.6,4.5,4.5,4.3,4.5,4.6,4.4,4.4,4.5,4.7,4.6,4.5,4.5,4.7,4.5,4.8,4.7,4.4,4.6,4.5,4.6,4.7,4.6,4.5,4.6,4.5,4.6,4.4,4.7,4.3,4.3,4.4,4.3,4.5,4.4,4.5,4.4,4.5,4.6,4.7,4.6,4.4,4.4,4.5,4.6,4.3,4.5,4.5,4.4,4.5,4.2,4.5,4.4,4.7,4.2,4.5,4.5,4.6,4.4,4.5,4.3,4.3,4.5,4.7,4.7,4.1,4.8,4.4,4.2,4.4,4.7,4.3,4.7,4.2,4.3,4.4,4.1,4.1,4.2,4.5,4.7,4.6,4.5,3.1,4.1,3.4,4.4,4.3,4.6,4.4,4.3,4.6,4.2,4.2,4.5,4.4,4.2,4.5,4.8,4.4,4.6,4.5,4.3,4.6,4.4,4.4,4.5,4.6,4.6,4.6,4.